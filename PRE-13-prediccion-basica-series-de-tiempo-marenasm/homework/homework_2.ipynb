# %%
#=============================================================================
#
# Pronostico time trend + dummy seasonal
#
# =============================================================================

#
# Carga de datos
#
import nbimporter  #  type: ignore
import functions  #  type: ignore


df_orig = functions.load_data()
df_orig.head()
# Out:
#             yt_true
# date
# 1946-01-01      890
# 1946-02-01      992
# 1946-03-01      979
# 1946-04-01      959
# 1946-05-01     1110

# %%
functions.plot_time_series(df_orig)

# %%
#
# Componentes de tendencia lineal
#
df_orig = functions.add_linear_trend_component(df_orig)
df_orig.head()
# Out:
#             yt_true  trend
# date
# 1946-01-01      890      0
# 1946-02-01      992      1
# 1946-03-01      979      2
# 1946-04-01      959      3
# 1946-05-01     1110      4

# %%
#
# Componentes estacionales
#
df_orig = functions.add_month_component(df_orig)
df_orig.head(25)
# Out:
#             yt_true  trend  month
# date
# 1946-01-01      890      0      1
# 1946-02-01      992      1      2
# 1946-03-01      979      2      3
# 1946-04-01      959      3      4
# 1946-05-01     1110      4      5
# 1946-06-01     1546      5      6
# 1946-07-01     1539      6      7
# 1946-08-01     3401      7      8
# 1946-09-01     2092      8      9
# 1946-10-01     1436      9     10
# 1946-11-01     1301     10     11
# 1946-12-01     1287     11     12
# 1947-01-01     1488     12      1
# 1947-02-01     1517     13      2
# 1947-03-01     1707     14      3
# 1947-04-01     1729     15      4
# 1947-05-01     1788     16      5
# 1947-06-01     2008     17      6
# 1947-07-01     2203     18      7
# 1947-08-01     3713     19      8
# 1947-09-01     2946     20      9
# 1947-10-01     2082     21     10
# 1947-11-01     2033     22     11
# 1947-12-01     1937     23     12
# 1948-01-01     1711     24      1

# %%
#
# Particionamiento de los datos
#
(
    X_complete,
    y_complete,
    X_train,
    y_train,
    X_test,
    y_test,
) = functions.train_test_split(
    df=df_orig,
    x_columns=["trend", "month"],
    y_column="yt_true",
)

# %%
#
# Especificación del Modelo
#
from sklearn.pipeline import Pipeline  #  type: ignore
from sklearn.preprocessing import (  #  type: ignore
    PolynomialFeatures,
    OneHotEncoder,
    MinMaxScaler,
)
from sklearn.linear_model import LinearRegression  #  type: ignore
from sklearn.compose import ColumnTransformer  #  type: ignore


def create_pipeline(degree):
    pipeline = Pipeline(
        [
            (
                "preprocessor",
                ColumnTransformer(
                    [
                        (
                            "trend",
                            Pipeline(
                                [
                                    ("poly", PolynomialFeatures(degree=degree)),
                                    ("scaler", MinMaxScaler()),
                                ]
                            ),
                            ["trend"],
                        ),
                        ("seasonal", OneHotEncoder(), ["month"]),
                    ]
                ),
            ),
            ("regressor", LinearRegression()),
        ]
    )

    return pipeline

# %%
#
# Entrenamiento y pronostico
#
for degree in range(1, 4):
    pipeline = create_pipeline(degree=degree)
    pipeline.fit(X_train, y_train)
    df_orig[f"yt_pred_time_trend_{degree}_dummy"] = pipeline.predict(X_complete)

functions.plot_time_series(df_orig)

# %%
#
# Almacenamiento de los resultados
#
functions.save_forecasts(df_orig)

# %%
# Métricas de error
#
metrics = functions.compute_evaluation_metrics(df_orig)
functions.save_metrics(metrics)
metrics
# Out:
#      Metrics  yt_pred_time_trend_1_dummy  yt_pred_time_trend_2_dummy  \
# 0  MSE Train                   103217.67                    78075.48
# 1   MSE Test                   738282.04                   190079.09
# 2  MAE Train                      259.03                      213.47
# 3   MAE Test                      804.13                      341.66
#
#    yt_pred_time_trend_3_dummy
# 0                    68044.66
# 1                   107356.45
# 2                      202.35
# 3                      262.00
